# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"

import seaborn as sns
from sklearn.datasets import make_blobs  #to generate clustered data

# %%
X, y = make_blobs(
    n_samples=1000,
    n_features=2,
    centers=4,
    random_state=42
)

# %%
# Visualize 
sns.scatterplot(x=X[:,0], y=X[:,1])
# Out:
# <Axes: >

# %%
# K-means algo
from sklearn.cluster import KMeans

# %%
K = 4

kmeans = KMeans(
    n_clusters=K,
    init='k-means++',
    random_state=42
)

# %%
labels = kmeans.fit_predict(X)
#label = cluster numbers

# %%
# now creating the plot with labels which we created
sns.scatterplot(x=X[:,0], y=X[:,1], c=labels)
# Out:
# <Axes: >

# %% [markdown]
# # Choose our K value - Elbow, Silhoutte Score

# %%
# Elbow method

wcss=[]
for k in range(1, 21):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit_predict(X)
    wcss.append(kmeans.inertia_)  # Here we get the inertia which we append in the wcss list we created above

# %%
# Plotting k v/s wcss 
sns.lineplot(x=range(1, 21), y=wcss, marker='o')  #where x=k, y=wcss
# Out:
# <Axes: >

# %%
# Automatic way to do elbow method using kneed module
# !pip install kneed
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kneed in c:\users\syed maaz\appdata\roaming\python\python313\site-packages (0.8.5)
# Requirement already satisfied: numpy>=1.14.2 in c:\programdata\anaconda3\lib\site-packages (from kneed) (2.3.5)
# Requirement already satisfied: scipy>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from kneed) (1.16.3)

# %%
from kneed import KneeLocator

# %%
knee = KneeLocator(range(1,21), wcss, curve="convex", direction="decreasing")
print("k = ", knee.elbow)
# Out:
# k =  4

# %%
# Silhouette Score

from sklearn.metrics import silhouette_score

# %%
ss=[]
for k in range(2, 21):
    kmeans=KMeans(n_clusters=k)
    labels=kmeans.fit_predict(X)
    ss.append(silhouette_score(X, labels))

# %%
# Plotting k v/s ss
sns.lineplot(x=range(2,21), y=ss, marker="o")
# Out:
# <Axes: >

# %%
# K-Means on Iris Dataset
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import pandas as pd

# %%
df = load_iris()
X = df.data
y = df.target

# %%
X.shape
# Out:
# (150, 4)

# %%
#Visualize
sns.scatterplot(x=X[:,0], y=X[:,2])
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
#Elbow method 
wcss=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k)
    kmeans.fit_predict(X_scale)
    wcss.append(kmeans.inertia_)

# %%
sns.lineplot(x=range(1,11), y=wcss, marker="o")
# Out:
# <Axes: >

# %%
kmeans = KMeans(n_clusters=3)
labels = kmeans.fit_predict(X_scale)

sns.scatterplot(x=X[:,0], y=X[:,2], c=labels)
#Here we have created our labels and plotted them
# Out:
# <Axes: >
