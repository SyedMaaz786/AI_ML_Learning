# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %%
df = load_iris()

X = pd.DataFrame(df.data)
y = df.target

# %%
X.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
scaler = StandardScaler()
X_scale = scaler.fit_transform(X)
X_scale.shape
# The number features here are 4
# Out:
# (150, 4)

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(
    n_components=2
)
label = pca.fit_transform(X_scale)
label.shape
# Now the number of features are 2
# Out:
# (150, 2)

# %%
# variance 
print(f"Explained Variance Ratio for PC-1 and PC-2: ", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio for PC-1 and PC-2:  [0.72962445 0.22850762]

# %%
# eigen vectors
print(f"For PC-1 and PC-2: \n" , pca.components_)
# Out:
# For PC-1 and PC-2:
#  [[ 0.52106591 -0.26934744  0.5804131   0.56485654]
#  [ 0.37741762  0.92329566  0.02449161  0.06694199]]

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    label[:,0],
    label[:,1],
)

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA for iris dataset")
# Now this pc1 will become X axis and pc2 will become Y axis by rorating this axis
# Out:
# Text(0.5, 1.0, 'PCA for iris dataset')
