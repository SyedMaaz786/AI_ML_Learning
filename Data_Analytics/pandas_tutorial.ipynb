# %%
import pandas as pd

# %%
info = {
    "Name": ["Syed", "Maaz", "Khan"],
    "Age": [20, 22, 23]
}
df = pd.DataFrame(info)
print(df)
# Out:
#   Cell In[7], line 6
#     print(df0
#              ^
# _IncompleteInputError: incomplete input
